# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
raw_data = pd.read_csv('NFLCombineData.csv')
raw_data
# Out:
#       year                   name     firstname     lastname position  \
# 0     2015         Ameer Abdullah         Ameer     Abdullah       RB
# 1     2015         Nelson Agholor        Nelson      Agholor       WR
# 2     2015              Jay Ajayi           Jay        Ajayi       RB
# 3     2015         Kwon Alexander          Kwon    Alexander      OLB
# 4     2015           Mario Alford         Mario       Alford       WR
# 5     2015         Javorius Allen      Javorius        Allen       RB
# 6     2015            Adrian Amos        Adrian         Amos       FS
# 7     2015          Dres Anderson          Dres     Anderson       WR
# 8     2015         Henry Anderson         Henry     Anderson       DE
# 9     2015  Rory 'Busta' Anderson  Rory 'Busta'     Anderson       TE
# 10    2015       Stephone Anthony      Stephone      Anthony      ILB
# 11    2015          Arik Armstead          Arik     Armstead       DT
# ...

# %%
raw_data = raw_data.groupby('position')
raw_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d6fc09e9e0c1> in <module>
# ----> 1 raw_data = raw_data.groupby('position')
#       2 raw_data
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# ...
