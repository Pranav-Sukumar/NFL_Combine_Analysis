# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\Public\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
raw_data = pd.read_csv('NFLCombineData.csv')
raw_data
# Out:
#       year            name firstname   lastname position  heightfeet  \
# 0     2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1     2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2     2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3     2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4     2015    Mario Alford     Mario     Alford       WR           5
# ...    ...             ...       ...        ...      ...         ...
# 4940  1999    Daren Yancey     Daren     Yancey       DT           6
# 4941  1999     Craig Yeast     Craig      Yeast       WR           5
# 4942  1999      Ryan Young      Ryan      Young       OT           6
# 4943  1999   Peppi Zellner     Peppi    Zellner       DE           6
# 4944  1999    Amos Zereoue      Amos    Zereoue       RB           5
#
#       heightinches  heightinchestotal  weight  arms  ...  threecone  vertical  \
# 0              9.0               69.0     205   0.0  ...       6.79      42.5
# 1              0.0               72.0     198   0.0  ...       0.00       0.0
# 2              0.0               72.0     221   0.0  ...       7.10      39.0
# 3              1.0               73.0     227   0.0  ...       7.14      36.0
# 4              8.0               68.0     180   0.0  ...       6.64      34.0
# ...            ...                ...     ...   ...  ...        ...       ...
# 4940           6.0               78.0     303   0.0  ...       0.00      26.5
# 4941           8.0               68.0     164   0.0  ...       0.00      32.5
# 4942           6.0               78.0     335   0.0  ...       0.00       0.0
# 4943           5.0               77.0     246   0.0  ...       0.00      35.5
# 4944           8.0               68.0     203   0.0  ...       0.00       0.0
#
#       broad  bench  round            college  pickround  picktotal  wonderlic  \
# 0       130     24      0           Nebraska          0          0          0
# 1         0     12      0                USC          0          0          0
# 2       121     19      0          Boise St.          0          0          0
# 3       121     24      0                LSU          0          0          0
# 4       121     13      0      West Virginia          0          0          0
# ...     ...    ...    ...                ...        ...        ...        ...
# 4940     97      0      6      Brigham Young         19        188          0
# 4941    112      0      4           Kentucky          3         98          0
# 4942      0     20      7       Kansas State         17        223          0
# 4943    122     20      4  Fort Valley State         37        132          0
# 4944      0      0      3      West Virginia         34         95          0
#
#       nflgrade
# 0          5.9
# 1          5.6
# 2          6.0
# 3          5.4
# 4          5.3
# ...        ...
# 4940       0.0
# 4941       0.0
# 4942       0.0
# 4943       0.0
# 4944       0.0
#
# [4945 rows x 25 columns]

# %%
ot_data = raw_data.loc[raw_data['position'] == 'OT']
dt_data = raw_data.loc[raw_data['position'] == 'DT']
og_data = raw_data.loc[raw_data['position'] == 'OG']
c_data = raw_data.loc[raw_data['position'] == 'C']
nt_data = raw_data.loc[raw_data['position'] == 'NT']

# %%
ot_data
# Out:
#       year              name firstname    lastname position  heightfeet  \
# 26    2015       Brett Boyko     Brett       Boyko       OT           6
# 32    2015       Jamon Brown     Jamon       Brown       OT           6
# 50    2015    T.J. Clemmings      T.J.   Clemmings       OT           6
# 53    2015    Takoby Cofield    Takoby     Cofield       OT           6
# 57    2015     La'el Collins     La'el     Collins       OT           6
# ...    ...               ...       ...         ...      ...         ...
# 4906  1999        Rex Tucker       Rex      Tucker       OT           6
# 4920  1999  Floyd Wedderburn     Floyd  Wedderburn       OT           6
# 4921  1999     John Welbourn      John    Welbourn       OT           6
# 4936  1999          Joe Wong       Joe        Wong       OT           6
# 4942  1999        Ryan Young      Ryan       Young       OT           6
#
#       heightinches  heightinchestotal  weight  arms  ...  threecone  vertical  \
# 26             7.0               79.0     301   0.0  ...       7.91      25.0
# 32             4.0               76.0     323   0.0  ...       0.00       0.0
# 50             5.0               77.0     309   0.0  ...       7.68      32.5
# 53             4.0               76.0     310   0.0  ...       8.09      30.0
# 57             4.0               76.0     305   0.0  ...       7.70      27.0
# ...            ...                ...     ...   ...  ...        ...       ...
# 4906           5.0               77.0     303   0.0  ...       0.00      30.0
# 4920           5.0               77.0     334   0.0  ...       0.00      24.5
# 4921           5.0               77.0     317   0.0  ...       0.00      30.0
# 4936           6.0               78.0     314   0.0  ...       0.00      27.0
# 4942           6.0               78.0     335   0.0  ...       0.00       0.0
#
#       broad  bench  round        college  pickround  picktotal  wonderlic  \
# 26      103      0      0           UNLV          0          0          0
# 32        0      0      0     Louisville          0          0          0
# 50      111     22      0     Pittsburgh          0          0          0
# 53      101     23      0           Duke          0          0          0
# 57      108     21      0            LSU          0          0          0
# ...     ...    ...    ...            ...        ...        ...        ...
# 4906    106     27      3      Texas A&M          5         66          0
# 4920     86     20      5     Penn State          7        140          0
# 4921     99     24      4     California          2         97          0
# 4936    100     22      7  Brigham Young         38        244          0
# 4942      0     20      7   Kansas State         17        223          0
#
#       nflgrade
# 26         4.8
# 32         5.3
# 50         6.1
# 53         4.9
# 57         6.2
# ...        ...
# 4906       0.0
# 4920       0.0
# 4921       0.0
# 4936       0.0
# 4942       0.0
#
# [390 rows x 25 columns]

# %%
dt_data
# Out:
#       year             name firstname    lastname position  heightfeet  \
# 11    2015    Arik Armstead      Arik    Armstead       DT           6
# 20    2015  Michael Bennett   Michael     Bennett       DT           6
# 22    2015  Angelo Blackson    Angelo    Blackson       DT           6
# 34    2015     Malcom Brown    Malcom       Brown       DT           6
# 61    2015    Xavier Cooper    Xavier      Cooper       DT           6
# ...    ...              ...       ...         ...      ...         ...
# 4895  1999  Pene Talamaivao      Pene  Talamaivao       DT           6
# 4905  1999    John Thornton      John    Thornton       DT           6
# 4924  1999      Chris White     Chris       White       DT           6
# 4932  1999      Jason Wiltz     Jason       Wiltz       DT           6
# 4940  1999     Daren Yancey     Daren      Yancey       DT           6
#
#       heightinches  heightinchestotal  weight  arms  ...  threecone  vertical  \
# 11             7.0               79.0     292   0.0  ...       7.57      34.0
# 20             2.0               74.0     293   0.0  ...       0.00       0.0
# 22             4.0               76.0     318   0.0  ...       7.50      31.0
# 34             2.0               74.0     319   0.0  ...       7.84      29.5
# 61             3.0               75.0     293   0.0  ...       7.23      29.0
# ...            ...                ...     ...   ...  ...        ...       ...
# 4895           4.0               76.0     301   0.0  ...       0.00      27.5
# 4905           3.0               75.0     299   0.0  ...       0.00      32.0
# 4924           3.0               75.0     282   0.0  ...       0.00      29.0
# 4932           4.0               76.0     308   0.0  ...       0.00      27.5
# 4940           6.0               78.0     303   0.0  ...       0.00      26.5
#
#       broad  bench  round              college  pickround  picktotal  \
# 11      117     24      0               Oregon          0          0
# 20        0      0      0             Ohio St.          0          0
# 22      101     20      0               Auburn          0          0
# 34       98     26      0                Texas          0          0
# 61      110     29      0       Washington St.          0          0
# ...     ...    ...    ...                  ...        ...        ...
# 4895    103     17      0                  NaN          0          0
# 4905    111     26      2        West Virginia         21         52
# 4924    107     25      7  Southern University         40        246
# 4932    101      0      4             Nebraska         28        123
# 4940     97      0      6        Brigham Young         19        188
#
#       wonderlic  nflgrade
# 11            0       6.2
# 20            0       6.0
# 22            0       5.0
# 34            0       6.1
# 61            0       5.4
# ...         ...       ...
# 4895          0       0.0
# 4905          0       0.0
# 4924          0       0.0
# 4932          0       0.0
# 4940          0       0.0
#
# [369 rows x 25 columns]

# %%
og_data
# Out:
#       year            name firstname  lastname position  heightfeet  \
# 23    2015         Al Bond        Al      Bond       OG           6
# 35    2015   Trenton Brown   Trenton     Brown       OG           6
# 38    2015       A.J. Cann      A.J.      Cann       OG           6
# 89    2015   Jamil Douglas     Jamil   Douglas       OG           6
# 99    2015   Tayo Fabuluje      Tayo  Fabuluje       OG           6
# ...    ...             ...       ...       ...      ...         ...
# 4867  1999     Bobby Singh     Bobby     Singh       OG           6
# 4880  1999  Cameron Spikes   Cameron    Spikes       OG           6
# 4902  1999    Randy Thomas     Randy    Thomas       OG           6
# 4934  1999       Brad Winn      Brad      Winn       OG           6
# 4935  1999     Jerry Wisne     Jerry     Wisne       OG           6
#
#       heightinches  heightinchestotal  weight  arms  ...  threecone  vertical  \
# 23             4.0               76.0     303   0.0  ...       7.90      23.5
# 35             8.0               80.0     355   0.0  ...       8.23      23.5
# 38             3.0               75.0     313   0.0  ...       0.00       0.0
# 89             4.0               76.0     304   0.0  ...       7.99      29.0
# 99             6.0               78.0     353   0.0  ...       0.00      29.5
# ...            ...                ...     ...   ...  ...        ...       ...
# 4867           3.0               75.0     316   0.0  ...       0.00      26.0
# 4880           3.0               75.0     314   0.0  ...       0.00      32.5
# 4902           4.0               76.0     306   0.0  ...       0.00      31.0
# 4934           5.0               77.0     339   0.0  ...       0.00      23.0
# 4935           7.0               79.0     306   0.0  ...       0.00      28.0
#
#       broad  bench  round            college  pickround  picktotal  wonderlic  \
# 23       90     22      0            Memphis          0          0          0
# 35       97     20      0            Florida          0          0          0
# 38        0     26      0     South Carolina          0          0          0
# 89       99     28      0      Arizona State          0          0          0
# 99        0      0      0                TCU          0          0          0
# ...     ...    ...    ...                ...        ...        ...        ...
# 4867     94     24      0                NaN          0          0          0
# 4880    117     23      5          Texas A&M         12        145          0
# 4902    107     31      2  Mississippi State         26         57          0
# 4934     87     23      0                NaN          0          0          0
# 4935    100     30      5         Notre Dame         10        143          0
#
#       nflgrade
# 23         5.0
# 35         5.3
# 38         6.0
# 89         5.2
# 99         5.3
# ...        ...
# 4867       0.0
# 4880       0.0
# 4902       0.0
# 4934       0.0
# 4935       0.0
#
# [330 rows x 25 columns]

# %%
c_data
# Out:
#      year                name  firstname   lastname position  heightfeet  \
# 85   2015      Reese Dismukes      Reese   Dismukes        C           6
# 97   2015      Cameron Erving    Cameron     Erving        C           6
# 103  2015         B.J. Finney       B.J.     Finney        C           6
# 111  2015         Andy Gallik       Andy     Gallik        C           6
# 112  2015          Max Garcia        Max     Garcia        C           6
# 123  2015       Hroniss Grasu    Hroniss      Grasu        C           6
# 137  2015       Chad Hamilton       Chad   Hamilton        C           6
# 194  2015          Greg Mancz       Greg      Mancz        C           6
# 199  2015          Ali Marpet        Ali     Marpet        C           6
# 327  2014      Matt Armstrong       Matt  Armstrong        C           6
# 342  2014      Russell Bodine    Russell     Bodine        C           6
# 441  2014  Jonotthan Harrison  Jonotthan   Harrison        C           6
# 460  2014          Gabe Ikard       Gabe      Ikard        C           6
# 489  2014        Tyler Larsen      Tyler     Larsen        C           6
# 500  2014       Corey Linsley      Corey    Linsley        C           6
# 516  2014       Marcus Martin     Marcus     Martin        C           6
# 551  2014     Matthew Paradis    Matthew    Paradis        C           6
# 575  2014     Weston Richburg     Weston   Richburg        C           6
# 607  2014         James Stone      James      Stone        C           6
# 608  2014         Bryan Stork      Bryan      Stork        C           6
# 613  2014      Travis Swanson     Travis    Swanson        C           6
#
#      heightinches  heightinchestotal  weight  arms  ...  threecone  vertical  \
# 85            3.0               75.0     296   0.0  ...       8.14      27.5
# 97            5.0               77.0     313   0.0  ...       7.48      30.5
# 103           4.0               76.0     318   0.0  ...       0.00      24.0
# 111           2.0               74.0     306   0.0  ...       7.66      27.0
# 112           4.0               76.0     309   0.0  ...       0.00       0.0
# 123           3.0               75.0     297   0.0  ...       0.00       0.0
# 137           2.0               74.0     292   0.0  ...       0.00       0.0
# 194           4.0               76.0     301   0.0  ...       0.00       0.0
# 199           4.0               76.0     307   0.0  ...       7.33      30.5
# 327           2.0               74.0     302   0.0  ...       0.00       0.0
# 342           3.0               75.0     310   0.0  ...       8.26      29.0
# 441           3.0               75.0     304   0.0  ...       7.97      27.0
# 460           4.0               76.0     304   0.0  ...       7.30      26.0
# 489           4.0               76.0     313   0.0  ...       8.22      23.5
# 500           3.0               75.0     296   0.0  ...       0.00      27.0
# 516           3.0               75.0     320   0.0  ...       0.00       0.0
# 551           3.0               75.0     306   0.0  ...       7.60      26.0
# 575           3.0               75.0     298   0.0  ...       7.93      25.5
# 607           4.0               76.0     306   0.0  ...       8.16      27.5
# 608           4.0               76.0     315   0.0  ...       0.00       0.0
# 613           5.0               77.0     312   0.0  ...       7.73      26.0
#
#      broad  bench  round                 college  pickround  picktotal  \
# 85     107     23      0                  Auburn          0          0
# 97     112     30      0             Florida St.          0          0
# 103     99     20      0              Kansas St.          0          0
# 111     96     29      0          Boston College          0          0
# 112      0      0      0                 Florida          0          0
# 123      0      0      0                  Oregon          0          0
# 137      0      0      0        Coastal Carolina          0          0
# 194      0      0      0                  Toledo          0          0
# 199    108     30      0  Hobart & William Smith          0          0
# 327      0      0      0        Grand Valley St.          0          0
# 342    109     42      4          North Carolina         15        111
# 441    113     27      0                 Florida          0          0
# 460    103     22      0                Oklahoma          0          0
# 489    102     36      0                Utah St.          0          0
# 500      0     36      6                Ohio St.          1        161
# 516      0     23      3                     USC          6         70
# 551    103     23      7               Boise St.         15        207
# 575    106     25      2            Colorado St.         11         43
# 607    105     22      0               Tennessee          0          0
# 608      0      0      4             Florida St.          9        105
# 613     95     20      3                Arkansas         12         76
#
#      wonderlic  nflgrade
# 85           0       5.3
# 97           0       5.8
# 103          0       5.6
# 111          0       5.5
# 112          0       5.2
# 123          0       5.7
# 137          0       5.2
# 194          0       5.4
# 199          0       5.4
# 327          0       5.1
# 342          0       5.3
# 441          0       5.2
# 460          0       5.2
# 489          0       5.2
# 500          0       5.1
# 516          0       5.5
# 551          0       5.0
# 575          0       5.3
# 607          0       5.1
# 608          0       5.2
# 613          0       5.5
#
# [21 rows x 25 columns]

# %%
nt_data
# Out:
#      year             name  firstname    lastname position  heightfeet  \
# 165  2015    Grady Jarrett      Grady     Jarrett       NT           6
# 228  2015      David Parry      David       Parry       NT           6
# 235  2015  Jordan Phillips     Jordan    Phillips       NT           6
# 266  2015    Danny Shelton      Danny     Shelton       NT           6
# 270  2015       Deon Simon       Deon       Simon       NT           6
# 368  2014  Ryan Carrethers       Ryan  Carrethers       NT           6
# 471  2014   Timmy Jernigan      Timmy    Jernigan       NT           6
# 484  2014   Zachariah Kerr  Zachariah        Kerr       NT           6
# 546  2014        Louis Nix      Louis         Nix       NT           6
#
#      heightinches  heightinchestotal  weight  arms  ...  threecone  vertical  \
# 165           1.0               73.0     304   0.0  ...       7.37      31.0
# 228           1.0               73.0     308   0.0  ...       0.00      29.0
# 235           5.0               77.0     329   0.0  ...       7.88      30.0
# 266           2.0               74.0     339   0.0  ...       7.99      30.5
# 270           4.0               76.0     321   0.0  ...       7.92      29.5
# 368           1.0               73.0     337   0.0  ...       7.89      26.0
# 471           2.0               74.0     299   0.0  ...       0.00      29.5
# 484           1.0               73.0     326   0.0  ...       7.93      28.5
# 546           2.0               74.0     331   0.0  ...       8.29      25.5
#
#      broad  bench  round                college  pickround  picktotal  \
# 165    112     30      0                Clemson          0          0
# 228    103     34      0               Stanford          0          0
# 235    105     28      0               Oklahoma          0          0
# 266     95     34      0             Washington          0          0
# 270    105     35      0  Northwestern St. (LA)          0          0
# 368     88     32      6         Arkansas State          5        165
# 471    102     27      2            Florida St.         16         48
# 484     99     28      0               Delaware          0          0
# 546     97      0      3             Notre Dame         19         83
#
#      wonderlic  nflgrade
# 165          0       5.8
# 228          0       5.4
# 235          0       6.2
# 266          0       6.4
# 270          0       5.0
# 368          0       5.2
# 471          0       5.6
# 484          0       5.1
# 546          0       5.9
#
# [9 rows x 25 columns]

# %%
dt_nt_data = raw_data.loc[(raw_data['position'] == 'NT') | (raw_data['position'] == 'DT')]

# %%
dt_nt_data
# Out:
#       year             name firstname    lastname position  heightfeet  \
# 11    2015    Arik Armstead      Arik    Armstead       DT           6
# 20    2015  Michael Bennett   Michael     Bennett       DT           6
# 22    2015  Angelo Blackson    Angelo    Blackson       DT           6
# 34    2015     Malcom Brown    Malcom       Brown       DT           6
# 61    2015    Xavier Cooper    Xavier      Cooper       DT           6
# ...    ...              ...       ...         ...      ...         ...
# 4895  1999  Pene Talamaivao      Pene  Talamaivao       DT           6
# 4905  1999    John Thornton      John    Thornton       DT           6
# 4924  1999      Chris White     Chris       White       DT           6
# 4932  1999      Jason Wiltz     Jason       Wiltz       DT           6
# 4940  1999     Daren Yancey     Daren      Yancey       DT           6
#
#       heightinches  heightinchestotal  weight  arms  ...  threecone  vertical  \
# 11             7.0               79.0     292   0.0  ...       7.57      34.0
# 20             2.0               74.0     293   0.0  ...       0.00       0.0
# 22             4.0               76.0     318   0.0  ...       7.50      31.0
# 34             2.0               74.0     319   0.0  ...       7.84      29.5
# 61             3.0               75.0     293   0.0  ...       7.23      29.0
# ...            ...                ...     ...   ...  ...        ...       ...
# 4895           4.0               76.0     301   0.0  ...       0.00      27.5
# 4905           3.0               75.0     299   0.0  ...       0.00      32.0
# 4924           3.0               75.0     282   0.0  ...       0.00      29.0
# 4932           4.0               76.0     308   0.0  ...       0.00      27.5
# 4940           6.0               78.0     303   0.0  ...       0.00      26.5
#
#       broad  bench  round              college  pickround  picktotal  \
# 11      117     24      0               Oregon          0          0
# 20        0      0      0             Ohio St.          0          0
# 22      101     20      0               Auburn          0          0
# 34       98     26      0                Texas          0          0
# 61      110     29      0       Washington St.          0          0
# ...     ...    ...    ...                  ...        ...        ...
# 4895    103     17      0                  NaN          0          0
# 4905    111     26      2        West Virginia         21         52
# 4924    107     25      7  Southern University         40        246
# 4932    101      0      4             Nebraska         28        123
# 4940     97      0      6        Brigham Young         19        188
#
#       wonderlic  nflgrade
# 11            0       6.2
# 20            0       6.0
# 22            0       5.0
# 34            0       6.1
# 61            0       5.4
# ...         ...       ...
# 4895          0       0.0
# 4905          0       0.0
# 4924          0       0.0
# 4932          0       0.0
# 4940          0       0.0
#
# [378 rows x 25 columns]
